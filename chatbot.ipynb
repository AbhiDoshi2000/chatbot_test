# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to /home/caypro/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/caypro/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# INITIALIZING CHATBOT TRAINING

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('/home/caypro/Documents/Abhishek/INTENTS.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 25 documents
# 4 classes ['Name', 'age', 'goodbye', 'greetings']
# 39 unique lemmatized words ["'s", 'a', 'age', 'am', 'are', 'bye', 'call', 'can', 'ciao', 'cya', 'day', 'going', 'good', 'goodbye', 'greeting', 'have', 'hello', 'hey', 'hi', 'how', 'i', 'is', 'it', 'later', 'leaving', 'me', 'name', 'old', 'see', 'should', 'stark', 'tell', 'tour', 'up', 'what', 'who', 'ya', 'you', 'your']

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# /tmp/ipykernel_378244/74795701.py:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 5/5 [==============================] - 0s 2ms/step - loss: 1.4271 - accuracy: 0.3200
# Epoch 2/200
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3083 - accuracy: 0.4000
# Epoch 3/200
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3586 - accuracy: 0.2000
# Epoch 4/200
# 5/5 [==============================] - 0s 2ms/step - loss: 1.2479 - accuracy: 0.5600
# Epoch 5/200
# 5/5 [==============================] - 0s 2ms/step - loss: 1.2219 - accuracy: 0.6000
# Epoch 6/200
# 5/5 [==============================] - 0s 2ms/step - loss: 1.1494 - accuracy: 0.5600
# Epoch 7/200
# 5/5 [==============================] - 0s 2ms/step - loss: 1.1918 - accuracy: 0.5600
# Epoch 8/200
# 5/5 [==============================] - 0s 1ms/step - loss: 1.1080 - accuracy: 0.4800
# Epoch 9/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.9929 - accuracy: 0.6400
# Epoch 10/200
# 5/5 [==============================] - 0s 2ms/step - loss: 1.0357 - accuracy: 0.6000
# Epoch 11/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8056 - accuracy: 0.7600
# Epoch 12/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.8042 - accuracy: 0.7600
# Epoch 13/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8116 - accuracy: 0.6800
# Epoch 14/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6787 - accuracy: 0.8400
# Epoch 15/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7180 - accuracy: 0.8800
# Epoch 16/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6719 - accuracy: 0.9200
# Epoch 17/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6322 - accuracy: 0.8000
# Epoch 18/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3814 - accuracy: 1.0000
# Epoch 19/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7672 - accuracy: 0.6400
# Epoch 20/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4007 - accuracy: 0.9600
# Epoch 21/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5926 - accuracy: 0.8000
# Epoch 22/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3950 - accuracy: 0.9600
# Epoch 23/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4526 - accuracy: 0.8000
# Epoch 24/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3652 - accuracy: 0.9200
# Epoch 25/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2912 - accuracy: 0.9600
# Epoch 26/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2178 - accuracy: 0.9600
# Epoch 27/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2007 - accuracy: 1.0000
# Epoch 28/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3707 - accuracy: 0.7600
# Epoch 29/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.9200
# Epoch 30/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3513 - accuracy: 0.8400
# Epoch 31/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1619 - accuracy: 1.0000
# Epoch 32/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3154 - accuracy: 0.8800
# Epoch 33/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 1.0000
# Epoch 34/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2011 - accuracy: 0.9600
# Epoch 35/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1555 - accuracy: 0.9600
# Epoch 36/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1502 - accuracy: 1.0000
# Epoch 37/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1265 - accuracy: 0.9600
# Epoch 38/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1135 - accuracy: 0.9600
# Epoch 39/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1764 - accuracy: 0.9200
# Epoch 40/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0800 - accuracy: 1.0000
# Epoch 41/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2780 - accuracy: 0.8800
# Epoch 42/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 1.0000
# Epoch 43/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 1.0000
# Epoch 44/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0822 - accuracy: 1.0000
# Epoch 45/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.9600
# Epoch 46/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1031 - accuracy: 0.9600
# Epoch 47/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0705 - accuracy: 1.0000
# Epoch 48/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0858 - accuracy: 1.0000
# Epoch 49/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 1.0000
# Epoch 50/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1159 - accuracy: 0.9600
# Epoch 51/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1345 - accuracy: 0.9600
# Epoch 52/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0690 - accuracy: 1.0000
# Epoch 53/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 1.0000
# Epoch 54/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 55/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1280 - accuracy: 1.0000
# Epoch 56/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9600
# Epoch 57/200
# 5/5 [==============================] - ETA: 0s - loss: 0.3104 - accuracy: 1.00 - 0s 2ms/step - loss: 0.1352 - accuracy: 1.0000
# Epoch 58/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1300 - accuracy: 1.0000
# Epoch 59/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1113 - accuracy: 1.0000
# Epoch 60/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 61/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 1.0000
# Epoch 62/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1516 - accuracy: 0.9600
# Epoch 63/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 64/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1085 - accuracy: 0.9600
# Epoch 65/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0751 - accuracy: 1.0000
# Epoch 66/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 67/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0430 - accuracy: 1.0000
# Epoch 68/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 69/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 70/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0846 - accuracy: 0.9600
# Epoch 71/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 72/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 73/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 1.0000
# Epoch 74/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 75/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 1.0000
# Epoch 76/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 77/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0627 - accuracy: 1.0000
# Epoch 78/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 79/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 80/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0770 - accuracy: 0.9600
# Epoch 81/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 82/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 83/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0479 - accuracy: 1.0000
# Epoch 84/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 1.0000
# Epoch 85/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0822 - accuracy: 1.0000
# Epoch 86/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 87/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0606 - accuracy: 0.9600
# Epoch 88/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 89/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0529 - accuracy: 1.0000
# Epoch 90/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 91/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 92/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 93/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 94/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0903 - accuracy: 0.9600
# Epoch 95/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 96/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 97/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 98/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 99/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 100/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 101/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 102/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0909 - accuracy: 0.9600
# Epoch 103/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 104/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 105/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0611 - accuracy: 0.9600
# Epoch 106/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 107/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 108/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 109/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 110/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0466 - accuracy: 1.0000
# Epoch 111/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 112/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 113/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 114/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 115/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0424 - accuracy: 1.0000
# Epoch 116/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 117/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 118/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 119/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 120/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 121/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 122/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 123/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 124/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 125/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 126/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 127/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 1.0000
# Epoch 128/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 129/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 130/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 131/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 132/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 133/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 134/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 135/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 136/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 137/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 138/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 139/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 1.0000
# Epoch 140/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 141/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 142/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 143/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 144/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 145/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 146/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 147/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0684 - accuracy: 0.9600
# Epoch 148/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 149/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 150/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 151/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 152/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 153/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 154/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 155/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 156/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 157/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 158/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 159/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 160/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 161/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 162/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 163/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 164/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 165/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 166/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 167/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 168/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 169/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 170/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 171/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 172/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 173/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 174/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1118 - accuracy: 0.9600
# Epoch 175/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 176/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 177/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 178/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 179/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 180/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 181/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 182/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 183/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 184/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 185/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 186/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 187/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 188/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 189/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 190/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 191/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 192/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 193/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 194/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 195/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 196/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 197/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 198/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 199/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 200/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 1.0000
# model created

# %% [markdown]
# BUILDING CHATBOT GUI

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('/home/caypro/Documents/Abhishek/INTENTS.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter

import tkinter
from tkinter import *


def send(event):
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)


base = Tk()
base.title("COGBEE")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)
ChatLog.config(state=NORMAL)
ChatLog.insert(END, "Bot: Hello. My name is Cogbee. Let's have a conversation"+ '\n\n')
ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="black",width="29", height="5", font="Arial")
EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
